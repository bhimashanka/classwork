# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
data=pd.read_csv(r"C:\Users\BHIMA SHANKAR\Downloads\Student_Performance.csv")
data.head(10)
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
# 5              3               78                         No            9
# 6              7               73                        Yes            5
# 7              8               45                        Yes            4
# 8              5               77                         No            8
# 9              4               89                         No            4
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0
# 5                                 6               61.0
# 6                                 6               63.0
# 7                                 6               42.0
# 8                                 2               61.0
# 9                                 0               69.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
data.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# max                            9.000000         100.000000

# %%
data.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
sns.heatmap(data.isnull(), cbar=False, cmap='viridis')
plt.show()

# %%
data.hist(figsize=(10, 8))
plt.show()
x = data[["Performance Index", "Previous Scores", "Sleep Hours"]]
y = data["Performance Index"] 
x.head()
# Out:
#    Performance Index  Previous Scores  Sleep Hours
# 0               91.0               99            9
# 1               65.0               82            4
# 2               45.0               51            7
# 3               36.0               52            5
# 4               66.0               75            8

# %%
numerical_cols = data.select_dtypes(include=[np.number]).columns.tolist()
scaler = StandardScaler()
data[numerical_cols] = scaler.fit_transform(data[numerical_cols])
data
import matplotlib.pyplot as plt
import seaborn as sns

for col in numerical_cols:
    plt.figure(figsize=(6,4))
    sns.boxplot(data=data, x=col) 
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
polynomial = PolynomialFeatures(degree=2)
poly_features=polynomial.fit_transform(x_train)
model=LinearRegression()
model.fit(poly_features, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 9
#       7 from sklearn.preprocessing import PolynomialFeatures
#       8 polynomial = PolynomialFeatures(degree=2)
# ----> 9 poly_features=polynomial.fit_transform(x_train)
#      10 model=LinearRegression()
#      11 model.fit(poly_features, y_train)
#
# NameError: name 'x_train' is not defined
